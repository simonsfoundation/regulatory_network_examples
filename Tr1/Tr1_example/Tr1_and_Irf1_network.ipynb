# %% [markdown]
# # Synchronized network pair

# %%
directory = "/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1"

networkInits = [("Tr1Irf1_comb_koATAC_sp.tsv","Tr1: Irf1KO v Control",'Tr1 Irf1 Prior'),
    ("Tr1Batf_comb_koATAC_sp.tsv","Tr1: BatfKO v Control",'Tr1 BatfKO Prior')]

baseCompNet = ("Tr1Prior_KO_ATAC_all_sp.tsv","72h Tr1:Th0 micro","Tr1 ATAC + KO Prior")

expressionFile = "Tr1_ThVals.txt"

threshhold = 4

baseNetFile = baseCompNet[0]
baseCol = baseCompNet[1].lower()
baseNetName = baseCompNet[2]

# allow import without install
import sys
if ".." not in sys.path:
    sys.path.append("..")

# Load a pair of networks with coordinated display.
from jp_gene_viz import paired_networks
paired_networks.load_javascript_support()
from jp_gene_viz import paired_links

# %% [markdown]
# # Network pair with heatmaps

# %%
for networkInit in networkInits:
    currCol = networkInit[1].lower()
    networkFile = networkInit[0]
    LL = paired_links.PairedLinks()
    LL.load_left(directory + '/' + baseNetFile, directory + '/' + expressionFile)
    LL.load_right(directory + '/' + networkFile, directory + '/' + expressionFile)
    LL.show()    
    
#     N = L.network
#     N.set_title(networkInit[2])
#     N.threshhold_slider.value = threshhold
#     N.apply_click(None)
#     N.draw()
#     L.gene_click(None)    
#     L.expression.col = currCol    
#     L.condition_click(None)
#     N.layout_click(None)
#     N.labels_button.value=True
# Out:
# ('Reading network', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Prior_KO_ATAC_all_sp.tsv')
# Computing layout
# ('Saving layout', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Prior_KO_ATAC_all_sp.tsv.layout.json')
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-25e04e014c1a> in <module>()
#       3     networkFile = networkInit[0]
#       4     LL = paired_links.PairedLinks()
# ----> 5     LL.load_left(directory + '/' + baseNetFile, directory + '/' + expressionFile)
#       6     LL.load_right(directory + '/' + networkFile, directory + '/' + expressionFile)
#       7     LL.show()
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/paired_links.pyc in load_left(self, network_filename, heatmap_filename)
#      35     def load_left(self, network_filename, heatmap_filename):
#      36         "Load the left network and heatmap"
# ---> 37         self._load(self.left_expression, network_filename, heatmap_filename)
#      38
#      39     def load_right(self, network_filename, heatmap_filename):
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/paired_links.pyc in _load(self, expression, network_filename, heatmap_filename)
#      43     def _load(self, expression, network_filename, heatmap_filename):
#      44         expression.load_network(network_filename)
# ---> 45         expression.load_heatmap(heatmap_filename)
#      46
#      47     def show(self):
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/LExpression.pyc in load_heatmap(self, filename)
#      82         """
#      83         dexpr = self.expression
# ---> 84         dExpression.display_heat_map(filename, dexpr)
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dExpression.pyc in display_heat_map(filename, dexpr, side_length)
#     179     if dexpr is None:
#     180         dexpr = ExpressionDisplay()
# --> 181     dexpr.load_data(H, side_length=side_length)
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dExpression.pyc in load_data(self, heat_map, side_length)
#      48         cols = heat_map.col_names[:200]
#      49         self.side_length = side_length
# ---> 50         self.display_data(rows, cols, side_length)
#      51
#      52     def display_data(self, rows, cols, side_length=None):
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dExpression.pyc in display_data(self, rows, cols, side_length)
#      58             rows = self.rows
#      59         heat_map = self.display_heat_map = self.data_heat_map.projection(rows, cols)
# ---> 60         (self.dx, self.dy) = heat_map.fit(self.svg, side_length, self.labels_space)
#      61         self.row = self.col = None
#      62         self.svg.empty()
#
# /Users/emiraldi/anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/HMap.pyc in fit(self, canvas, side_length, label_space)
#     183         """
#     184         dx = max(1, side_length / self.ncols)
# --> 185         dy = max(1, side_length / self.nrows)
#     186         if label_space is None:
#     187             additional = 0
#
# ZeroDivisionError: integer division or modulo by zero
