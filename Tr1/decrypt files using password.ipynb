# %%
import encrypt_files
encrypt_files.decrypt_widget()
# Out:
# decrypting fineILCs_uv156_VSTcounts_zscore_FDR10_genes_clust.tsv.crypt to fineILCs_uv156_VSTcounts_zscore_FDR10_genes_clust.tsv
# Existing file matches fineILCs_uv156_VSTcounts_zscore_FDR10_genes_clust.tsv
# decrypting Ints_CCR6nILC3_up.txt.crypt to Ints_CCR6nILC3_up.txt
# Existing file matches Ints_CCR6nILC3_up.txt
# decrypting Ints_CCR6pILC3_up.txt.crypt to Ints_CCR6pILC3_up.txt
# Existing file matches Ints_CCR6pILC3_up.txt
# decrypting Ints_CCR6pILC3_up.txt.layout.json.crypt to Ints_CCR6pILC3_up.txt.layout.json
# Existing file matches Ints_CCR6pILC3_up.txt.layout.json
# decrypting Ints_ILC1_ILC2_up.txt.crypt to Ints_ILC1_ILC2_up.txt
# Existing file matches Ints_ILC1_ILC2_up.txt
# decrypting Ints_ILC1_ILC2_up.txt.layout.json.crypt to Ints_ILC1_ILC2_up.txt.layout.json
# Existing file matches Ints_ILC1_ILC2_up.txt.layout.json
# decrypting Ints_ILC1_ILC3_up.txt.crypt to Ints_ILC1_ILC3_up.txt
# Existing file matches Ints_ILC1_ILC3_up.txt
# ...
