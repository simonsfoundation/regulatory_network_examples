# %%
# IRF1 KO and BATF KO networks from Figures 7E-I, Supplemental Figures 7-8, Karwacz et al. 2016.
# INSTRUCTIONS to visualize networks:
# 1. Select "Cell" and then click "Run All"
# 2. Draft Documentation for this tool can be found here:
#    https://github.com/simonsfoundation/jp_gene_viz/blob/master/doc/dNetwork%20widget%20overview.ipynb

# %%
# list of tuples (network file, network title, network's gene expression condition for node coloring)
networkInits = [("Tr1Irf1_comb_koATAC_sp.tsv","Tr1: Irf1KO v Control",'Tr1 Irf1 Prior (dTF)'),
    ("Tr1Batf_comb_koATAC_sp.tsv","Tr1: BatfKO v Control",'Tr1 BatfKO Prior (dTF)')]

# gene expression data, log2-fold-changes estimated by DESeq2
expressionFile = "Tr1_72h_RNAseq.txt"

# Genes highlighted in Figure 7G (IRF1 KO):
# stat1 irf1 prf1 ccr5 il10 il13ra1 ccl3 zbp1 id3 klf7 ccl4
# Genes highlighted in Figure 7H (BATF KO):
# maf il23r il12rb2 il24 batf fosl2 il10 hlx klf10 prdm1 batf ets1 prf1 runx2 hif1a icos il2 csf2 cxcr5 nfkb2 il1rn

directory = "."

# %%
import sys
if ".." not in sys.path:
    sys.path.append("..")
    
from jp_gene_viz import LExpression

# %%
LExpression.load_javascript_support()

# %%
for networkInit in networkInits:
    currCol = networkInit[1].lower()
    networkFile = networkInit[0]
    L = LExpression.LinkedExpressionNetwork()
    L.show()
    print directory + '/' + networkFile
    try:
        L.load_network(directory + '/' + networkFile)
    except AssertionError:
        directory = "."
        L.load_network(directory + '/' + networkFile)
    L.load_heatmap(directory + '/' + expressionFile)
    N = L.network
    N.set_title(networkInit[2])
    N.threshhold_slider.value = networkInit[3]
    N.apply_click(None)
    N.draw()
    L.gene_click(None)    
    L.expression.col = currCol    
    L.condition_click(None)
    N.layout_click(None)
    N.labels_button.value=True
# Out:
# /Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Irf1_comb_koATAC_sp.tsv
# ('Reading network', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Irf1_comb_koATAC_sp.tsv')
# ('Loading saved layout', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Irf1_comb_koATAC_sp.tsv.layout.json')
# /Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Batf_comb_koATAC_sp.tsv
# ('Reading network', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Batf_comb_koATAC_sp.tsv')
# ('Loading saved layout', '/Users/emiraldi/erm/MariaP/Inferelator/input/GeneralPriors/Tr1/Tr1Batf_comb_koATAC_sp.tsv.layout.json')
# <canvas id="jp_svg_canvas_fake_svg_1" width="1000.0" height="1000.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_1");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(4.237288135593221, 4.237288135593221);
#     ctx.translate(10.0, -7.0);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.8821585464447, 74.822376247296418);
#     ctx.lineTo(90.501746362163303, 70.091529901528446);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(96.0421058931543, 72.39466174042893);
#     ctx.lineTo(98.739795636563059, 78.930904548671833);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.57266777218469, 75.770055294907166);
#     ctx.lineTo(155.94408467467429, 88.922945609074304);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(150.11229563433625, 87.512188156854663);
#     ctx.lineTo(151.28792684451929, 82.65236395657297);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.26809082565147, 75.01612182829102);
#     ctx.lineTo(80.41313875507926, 107.87179075722084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(83.62855131413508, 102.80610994660258);
#     ctx.lineTo(90.529462455530151, 101.26421973696722);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.25248069359144, 75.525681572446032);
#     ctx.lineTo(120.06318047543006, 109.60718471058684);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(117.16387610462564, 104.35418231524811);
#     ctx.lineTo(119.1252911250709, 97.560593343462159);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.45449248202647, 74.8431336483455);
#     ctx.lineTo(72.11339058895534, 90.529705235134728);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(77.404661307357387, 87.70084430101636);
#     ctx.lineTo(84.171437684457743, 89.75285245458609);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.94664211092442, 75.713320224814467);
#     ctx.lineTo(148.68259328727893, 47.79556568468724);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(143.53162508805343, 50.872500297344374);
#     ctx.lineTo(136.67503941148456, 49.144138975204058);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19529917509736, 75.355084102251908);
#     ctx.lineTo(107.60197803840275, 120.00814382921084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(106.74984330992794, 114.06896321194324);
#     ctx.lineTo(110.98904821725527, 108.4095337571579);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.0445994836266, 75.636809181659558);
#     ctx.lineTo(140.67461965015053, 36.828028992886694);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(136.4417839687838, 41.080452077969902);
#     ctx.lineTo(129.37073499674219, 41.096774914400299);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19592325172994, 75.359305551166301);
#     ctx.lineTo(103.83747386774994, 92.715309873678848);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.93468175230235, 86.783618176002236);
#     ctx.lineTo(107.87775816703287, 86.031291413129253);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19521102773591, 75.213678750174239);
#     ctx.lineTo(96.396520130425458, 108.95864443257202);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(97.241249626882649, 103.018406046967);
#     ctx.lineTo(102.89538952860114, 98.772148639343811);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.64476108452763, 74.786144670717974);
#     ctx.lineTo(63.575527810705893, 78.262550985750835);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.550666260638224, 77.716913281646498);
#     ctx.lineTo(74.984646389002108, 82.241497236503164);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18990759244242, 75.266095215487809);
#     ctx.lineTo(100.10451887042801, 17.304147524040125);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(100.32025078312239, 23.300267914913313);
#     ctx.lineTo(95.503260384640043, 28.476811501219618);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.1626709764581, 75.447781053458769);
#     ctx.lineTo(121.66095208102684, 19.178328737212741);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(119.69645393806957, 24.847609736274038);
#     ctx.lineTo(113.33497131972076, 27.934928783027402);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.42325080579511, 74.861318060680887);
#     ctx.lineTo(85.664351702316026, 84.813451351177747);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(90.737409472693358, 81.609690302283155);
#     ctx.lineTo(97.634758488753292, 83.167437570185442);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.72270421451634, 74.78512850583283);
#     ctx.lineTo(51.868204055368096, 71.540395619720982);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(57.85553648392213, 71.930075475481175);
#     ctx.lineTo(62.520246961250329, 77.244252379076357);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18234692894669, 75.372513857256578);
#     ctx.lineTo(110.94104767289735, 26.636091301745914);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(109.87975588436636, 32.541483730670237);
#     ctx.lineTo(104.0741857031536, 36.578234264331343);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.37079662595366, 74.899414911349211);
#     ctx.lineTo(67.21922018063654, 103.26015310356513);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(71.835115742994006, 99.426941896573197);
#     ctx.lineTo(78.876038050785183, 100.07917885937781);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.39549684456962, 75.687968703746023);
#     ctx.lineTo(113.08367827275042, 84.217160607392216);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(108.236928326
# <canvas id="jp_svg_canvas_fake_svg_2" width="1049.0" height="1049.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_2");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(4.444915254237288, 4.444915254237288);
#     ctx.translate(10.0, -7.0);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.68442830075678, 74.784106546091849);
#     ctx.lineTo(83.796779194663159, 74.991710001779254);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.796375140108992, 74.922078892424679);
#     ctx.lineTo(94.854064352442663, 79.863716255834063);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.57266777218469, 75.770055294907166);
#     ctx.lineTo(155.94408467467429, 88.922945609074304);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(150.11229563433625, 87.512188156854663);
#     ctx.lineTo(151.28792684451929, 82.65236395657297);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.26809082565147, 75.01612182829102);
#     ctx.lineTo(80.41313875507926, 107.87179075722084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(83.62855131413508, 102.80610994660258);
#     ctx.lineTo(90.529462455530151, 101.26421973696722);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.25248069359144, 75.525681572446032);
#     ctx.lineTo(120.06318047543006, 109.60718471058684);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(117.16387610462564, 104.35418231524811);
#     ctx.lineTo(119.1252911250709, 97.560593343462159);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.45449248202647, 74.8431336483455);
#     ctx.lineTo(72.11339058895534, 90.529705235134728);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(77.404661307357387, 87.70084430101636);
#     ctx.lineTo(84.171437684457743, 89.75285245458609);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.94664211092442, 75.713320224814467);
#     ctx.lineTo(148.68259328727893, 47.79556568468724);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(143.53162508805343, 50.872500297344374);
#     ctx.lineTo(136.67503941148456, 49.144138975204058);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19529917509736, 75.355084102251908);
#     ctx.lineTo(107.60197803840275, 120.00814382921084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(106.74984330992794, 114.06896321194324);
#     ctx.lineTo(110.98904821725527, 108.4095337571579);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.0445994836266, 75.636809181659558);
#     ctx.lineTo(140.67461965015053, 36.828028992886694);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(136.4417839687838, 41.080452077969902);
#     ctx.lineTo(129.37073499674219, 41.096774914400299);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19592325172994, 75.359305551166301);
#     ctx.lineTo(103.83747386774994, 92.715309873678848);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.93468175230235, 86.783618176002236);
#     ctx.lineTo(107.87775816703287, 86.031291413129253);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19521102773591, 75.213678750174239);
#     ctx.lineTo(96.396520130425458, 108.95864443257202);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(97.241249626882649, 103.018406046967);
#     ctx.lineTo(102.89538952860114, 98.772148639343811);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.64476108452763, 74.786144670717974);
#     ctx.lineTo(63.575527810705893, 78.262550985750835);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.550666260638224, 77.716913281646498);
#     ctx.lineTo(74.984646389002108, 82.241497236503164);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18990759244242, 75.266095215487809);
#     ctx.lineTo(100.10451887042801, 17.304147524040125);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(100.32025078312239, 23.300267914913313);
#     ctx.lineTo(95.503260384640043, 28.476811501219618);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.1626709764581, 75.447781053458769);
#     ctx.lineTo(121.66095208102684, 19.178328737212741);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(119.69645393806957, 24.847609736274038);
#     ctx.lineTo(113.33497131972076, 27.934928783027402);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.42325080579511, 74.861318060680887);
#     ctx.lineTo(85.664351702316026, 84.813451351177747);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(90.737409472693358, 81.609690302283155);
#     ctx.lineTo(97.634758488753292, 83.167437570185442);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.72522904113102, 74.785299249231443);
#     ctx.lineTo(45.011778085672169, 70.805807062829004);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(50.997061593442837, 71.225784837965335);
#     ctx.lineTo(55.63481637063812, 76.563502573721166);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18234692894669, 75.372513857256578);
#     ctx.lineTo(110.94104767289735, 26.636091301745914);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(109.87975588436636, 32.541483730670237);
#     ctx.lineTo(104.0741857031536, 36.578234264331343);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.37079662595366, 74.899414911349211);
#     ctx.lineTo(67.21922018063654, 103.26015310356513);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(71.835115742994006, 99.426941896573197);
#     ctx.lineTo(78.876038050785183, 100.07917885937781);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.39549684456962, 75.687968703746023);
#     ctx.lineTo(113.08367827275042, 84.217160607392216);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(108.2369
# <canvas id="jp_svg_canvas_fake_svg_3" width="1049.0" height="1049.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_3");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(4.444915254237288, 4.444915254237288);
#     ctx.translate(10.0, -7.0);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.68442830075678, 74.784106546091849);
#     ctx.lineTo(83.796779194663159, 74.991710001779254);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.796375140108992, 74.922078892424679);
#     ctx.lineTo(94.854064352442663, 79.863716255834063);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.57266777218469, 75.770055294907166);
#     ctx.lineTo(155.94408467467429, 88.922945609074304);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(150.11229563433625, 87.512188156854663);
#     ctx.lineTo(151.28792684451929, 82.65236395657297);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.26809082565147, 75.01612182829102);
#     ctx.lineTo(80.41313875507926, 107.87179075722084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(83.62855131413508, 102.80610994660258);
#     ctx.lineTo(90.529462455530151, 101.26421973696722);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.25248069359144, 75.525681572446032);
#     ctx.lineTo(120.06318047543006, 109.60718471058684);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(117.16387610462564, 104.35418231524811);
#     ctx.lineTo(119.1252911250709, 97.560593343462159);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.45449248202647, 74.8431336483455);
#     ctx.lineTo(72.11339058895534, 90.529705235134728);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(77.404661307357387, 87.70084430101636);
#     ctx.lineTo(84.171437684457743, 89.75285245458609);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.94664211092442, 75.713320224814467);
#     ctx.lineTo(148.68259328727893, 47.79556568468724);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(143.53162508805343, 50.872500297344374);
#     ctx.lineTo(136.67503941148456, 49.144138975204058);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19529917509736, 75.355084102251908);
#     ctx.lineTo(107.60197803840275, 120.00814382921084);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(106.74984330992794, 114.06896321194324);
#     ctx.lineTo(110.98904821725527, 108.4095337571579);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.0445994836266, 75.636809181659558);
#     ctx.lineTo(140.67461965015053, 36.828028992886694);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(136.4417839687838, 41.080452077969902);
#     ctx.lineTo(129.37073499674219, 41.096774914400299);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19592325172994, 75.359305551166301);
#     ctx.lineTo(103.83747386774994, 92.715309873678848);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.93468175230235, 86.783618176002236);
#     ctx.lineTo(107.87775816703287, 86.031291413129253);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.19521102773591, 75.213678750174239);
#     ctx.lineTo(96.396520130425458, 108.95864443257202);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(97.241249626882649, 103.018406046967);
#     ctx.lineTo(102.89538952860114, 98.772148639343811);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.64476108452763, 74.786144670717974);
#     ctx.lineTo(63.575527810705893, 78.262550985750835);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.550666260638224, 77.716913281646498);
#     ctx.lineTo(74.984646389002108, 82.241497236503164);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18990759244242, 75.266095215487809);
#     ctx.lineTo(100.10451887042801, 17.304147524040125);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(100.32025078312239, 23.300267914913313);
#     ctx.lineTo(95.503260384640043, 28.476811501219618);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.1626709764581, 75.447781053458769);
#     ctx.lineTo(121.66095208102684, 19.178328737212741);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(119.69645393806957, 24.847609736274038);
#     ctx.lineTo(113.33497131972076, 27.934928783027402);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.42325080579511, 74.861318060680887);
#     ctx.lineTo(85.664351702316026, 84.813451351177747);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(90.737409472693358, 81.609690302283155);
#     ctx.lineTo(97.634758488753292, 83.167437570185442);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.72522904113102, 74.785299249231443);
#     ctx.lineTo(45.011778085672169, 70.805807062829004);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(50.997061593442837, 71.225784837965335);
#     ctx.lineTo(55.63481637063812, 76.563502573721166);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(102.18234692894669, 75.372513857256578);
#     ctx.lineTo(110.94104767289735, 26.636091301745914);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(109.87975588436636, 32.541483730670237);
#     ctx.lineTo(104.0741857031536, 36.578234264331343);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.37079662595366, 74.899414911349211);
#     ctx.lineTo(67.21922018063654, 103.26015310356513);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(71.835115742994006, 99.426941896573197);
#     ctx.lineTo(78.876038050785183, 100.07917885937781);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(101.39549684456962, 75.687968703746023);
#     ctx.lineTo(113.08367827275042, 84.217160607392216);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(108.2369
# <canvas id="jp_svg_canvas_fake_svg_4" width="1064.0" height="1064.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_4");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(1.0431372549019609, 1.0431372549019609);
#     ctx.translate(10.0, -96.0);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.74556603471603, 403.93932288135261);
#     ctx.lineTo(764.53445301380373, 410.25835390912567);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(758.54802501712925, 409.85501801854252);
#     ctx.lineTo(753.89544826205315, 404.53021477916116);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.80866934714982, 402.94132441683035);
#     ctx.lineTo(648.03521117247249, 401.59571249137116);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(654.02476475006506, 401.94961634999316);
#     ctx.lineTo(658.72113951587392, 407.23583088017205);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.3431107589887, 403.19581962316522);
#     ctx.lineTo(634.60442740063434, 466.90090425161998);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(637.54003850220886, 461.6681050523087);
#     ctx.lineTo(644.34704708628033, 459.75378163752811);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.15517842862369, 403.77003421415907);
#     ctx.lineTo(737.34496106979259, 328.25755176475604);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(733.3899970794406, 332.76956460106527);
#     ctx.lineTo(726.33418305722296, 333.23377197269633);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.63115266690386, 402.96286756424809);
#     ctx.lineTo(568.5562646767097, 434.60029792725459);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(574.28730048528962, 432.82400162292498);
#     ctx.lineTo(580.54341057938086, 436.11961787646686);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.43426139377038, 403.80243865613983);
#     ctx.lineTo(711.65795807778159, 443.0822982814795);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(707.3141407836606, 438.94330669954854);
#     ctx.lineTo(707.14345269016883, 431.87429930283861);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.33806780556893, 403.67587342612939);
#     ctx.lineTo(755.12987125052314, 562.55169924548579);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(752.30483671652746, 557.25838460513694);
#     ctx.lineTo(754.36173680515515, 550.4930936265165);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.01433735793114, 403.8817018559825);
#     ctx.lineTo(841.35108251892359, 313.10193367586146);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(836.05610682669055, 315.92385366385923);
#     ctx.lineTo(829.29202709316485, 313.86297391032986);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.43983098814476, 403.80766504790063);
#     ctx.lineTo(767.70254652212657, 493.68987060413463);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(763.29601252687632, 489.61771415469605);
#     ctx.lineTo(763.01736457203333, 482.55213878412206);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.30389541005229, 403.59571839486387);
#     ctx.lineTo(707.42519250752616, 517.2281387200652);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(705.56201834871729, 511.52475533351765);
#     ctx.lineTo(708.76219270516617, 505.21929071238725);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.17764115905209, 403.74249129651952);
#     ctx.lineTo(790.6252420827235, 246.16087182486541);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(787.00079310404647, 250.94243742631508);
#     ctx.lineTo(779.99578095394088, 251.90670127862558);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.27052793034306, 403.53305310394478);
#     ctx.lineTo(694.42223343027308, 280.68532887744016);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(693.31104276249255, 286.58153573438113);
#     ctx.lineTo(687.47154482522467, 290.56904922534818);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.34889109264395, 403.18578992845909);
#     ctx.lineTo(583.89950706116883, 549.25272329147663);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(586.95547449921685, 544.08928809602867);
#     ctx.lineTo(593.80497669379679, 542.33306496486205);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.29280564317082, 403.55639591071412);
#     ctx.lineTo(686.14129798750537, 470.04012467244792);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(684.74999363849281, 464.20366408332211);
#     ctx.lineTo(688.45429050525388, 458.1805266348735);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.85571732786389, 402.9463469770476);
#     ctx.lineTo(600.69774149584396, 392.07847761363826);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(606.6270243508302, 392.9969572408296);
#     ctx.lineTo(610.80269370732594, 398.70342597597767);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.09238441933644, 403.05070866060402);
#     ctx.lineTo(658.50317460815006, 392.93376768206605);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(663.18011726045893, 396.69225240692714);
#     ctx.lineTo(663.94549886666539, 403.72177522123542);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.93601659318415, 402.96568925089264);
#     ctx.lineTo(566.56076677013436, 368.48516311781157);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(572.25794233898023, 370.36723392884551);
#     ctx.lineTo(575.4371963038235, 376.68327257874535);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.31387004703856, 403.62345416987858);
#     ctx.lineTo(705.22160608683043, 492.38191994263275);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(
# <canvas id="jp_svg_canvas_fake_svg_5" width="1064.0" height="1064.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_5");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(1.0462143559488692, 1.0462143559488692);
#     ctx.translate(-89.0, 9.0);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.26213949707778, 331.32174218626551);
#     ctx.lineTo(647.1107748004905, 233.83971116845728);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(648.55366304623806, 239.66363368771212);
#     ctx.lineTo(644.90280115164865, 245.71930932521408);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.55793353442186, 331.89152925109568);
#     ctx.lineTo(713.0792994077608, 352.59470507902392);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(707.68474287554591, 349.96815604640761);
#     ctx.lineTo(705.3780699592138, 343.28390140904827);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.35085475514836, 331.70382232224915);
#     ctx.lineTo(716.41508288562511, 406.64066002707818);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(713.2730094995685, 401.52916564317883);
#     ctx.lineTo(714.91419366443745, 394.65119250154885);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.18927789424265, 331.72459992515132);
#     ctx.lineTo(725.49259818198266, 252.47165417698622);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(722.10119356110044, 257.42123746221927);
#     ctx.lineTo(715.15037030600433, 258.71971968251165);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.29233834377681, 331.56561407990614);
#     ctx.lineTo(698.89220791472349, 443.64007745217305);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(697.40863343678291, 437.82638613181524);
#     ctx.lineTo(701.01706413879731, 431.74533129989999);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.56104434173778, 330.99093514878371);
#     ctx.lineTo(653.46297238292539, 339.17016176897187);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(658.87554507845402, 336.5809424241466);
#     ctx.lineTo(665.54370511208231, 338.9337368830661);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.6969718804786, 330.94839857844511);
#     ctx.lineTo(504.0886280535297, 357.89847295497765);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(510.01163959312203, 356.94038407504212);
#     ctx.lineTo(515.74588994272858, 361.0778196247561);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.17523640376032, 331.74407307337009);
#     ctx.lineTo(793.46752911257965, 170.45397516716);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(789.84244671307181, 175.2350605666042);
#     ctx.lineTo(782.83730688061178, 176.19839639988453);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.62947915318102, 331.91978288326425);
#     ctx.lineTo(783.60958343092511, 366.75810468110819);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(777.87598331268748, 364.99010307360157);
#     ctx.lineTo(774.57131788707829, 358.73876830214806);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.82585877408735, 330.94439421315479);
#     ctx.lineTo(534.55094074666863, 317.51209340495291);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(540.52200466974432, 318.10064724832131);
#     ctx.lineTo(545.00742973616707, 323.56699538702475);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.262420984595, 331.56108164206569);
#     ctx.lineTo(723.2564796816456, 119.56266996108096);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(721.82729445779114, 125.38997033054159);
#     ctx.lineTo(715.7802231300285, 129.0550662852134);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(671.13073400188568, 331.79516788976821);
#     ctx.lineTo(767.10539472962955, 235.62040697916203);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(762.86717453334472, 239.86746355611081);
#     ctx.lineTo(755.7961105556501, 239.87482720666412);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.27681546229462, 331.44029710553684);
#     ctx.lineTo(669.61582384875987, 527.48978493253378);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(669.63605306325121, 521.48981903439062);
#     ctx.lineTo(674.65288232377998, 516.50670513134742);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.481242213472, 331.03869868762513);
#     ctx.lineTo(624.96964387155288, 364.39453588462015);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(629.80905410098501, 360.84769100060453);
#     ctx.lineTo(636.79760002885814, 361.92482878845158);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.46387532103768, 331.05202102063328);
#     ctx.lineTo(596.43696687304987, 390.45726963729271);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(601.11650910638411, 386.70202204406519);
#     ctx.lineTo(608.1455006285189, 387.47226757748746);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.38248225834968, 331.74939719563361);
#     ctx.lineTo(705.43474409301461, 376.71207493486793);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(701.74577222634514, 371.98011058938511);
#     ctx.lineTo(702.61493262535623, 364.96266374592483);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.51552373715629, 331.86827868555912);
#     ctx.lineTo(796.49760047241386, 409.08629305508401);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(791.38205072663754, 405.95082645527975);
#     ctx.lineTo(789.73198143832747, 399.0749795006293);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(670.31632726347686, 331.2471669705904);
#     ctx.lineTo(649.46911896339009, 380.52360702219244);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(651.806909
# <canvas id="jp_svg_canvas_fake_svg_6" width="1064.0" height="1064.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_6");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(5.309215655699361, 5.309215655699361);
#     ctx.translate(5.609375, -9.359375);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(72.569783787485832, 79.44401091740211);
#     ctx.lineTo(43.407606776675905, 73.75294633387054);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(49.296516783475539, 74.902180396981777);
#     ctx.lineTo(53.24624673654921, 80.767300455240829);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(72.039756964632119, 79.686921656251897);
#     ctx.lineTo(41.865261267610634, 132.55946499121285);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(44.839242408212797, 127.3483771800795);
#     ctx.lineTo(51.660133201325735, 125.4841216213035);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(72.521664175565846, 80.432477726863496);
#     ctx.lineTo(122.7329068513471, 75.625478520320527);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(116.76021514461013, 76.197277240392012);
#     ctx.lineTo(111.30647312226975, 71.696533084837441);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.18920369317965, 118.75357958567878);
#     ctx.lineTo(129.46447159465106, 134.57318602985052);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(123.87982955478701, 132.37961057261569);
#     ctx.lineTo(121.05394073592933, 125.89776265836662);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.814171788973894, 118.05477131387616);
#     ctx.lineTo(49.894600866122332, 42.435142407626152);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.695658087889733, 47.741184099922272);
#     ctx.lineTo(50.608171029115795, 54.497099861641871);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.717559522197448, 117.92682070314129);
#     ctx.lineTo(43.657395145664857, 73.88231678855503);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(47.993859696250638, 78.029011279533705);
#     ctx.lineTo(48.15200141258989, 85.098310480837412);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.224631791011561, 117.81040396172703);
#     ctx.lineTo(42.15214872826742, 132.32950796563327);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(47.885614175824351, 130.5610696823814);
#     ctx.lineTo(54.137200618165018, 133.86525898596895);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(88.997601107698117, 117.95679535093515);
#     ctx.lineTo(67.926952914338742, 141.76163543882578);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(71.903721691398147, 137.26882895581258);
#     ctx.lineTo(78.961701074791989, 136.83879753418441);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(89.767812663718914, 118.59369829691964);
#     ctx.lineTo(123.08106797377751, 75.433259759321984);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(119.415001399023, 80.18299194855831);
#     ctx.lineTo(112.40183576236396, 81.086046627293157);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.816941537332823, 99.147545488990673);
#     ctx.lineTo(72.816941537332823, 80.298622759498485);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(68.450509438975971, 84.413749820773631);
#     ctx.lineTo(61.382543472615978, 84.204328956538873);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.240348495976285, 99.225717209282166);
#     ctx.lineTo(89.138335861698934, 118.73023381084467);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(83.833843119844204, 115.92624437584132);
#     ctx.lineTo(81.750090364134721, 109.16917589512624);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.807278634792524, 99.156415830495618);
#     ctx.lineTo(94.97262414564527, 61.456629057089309);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(90.499747949229146, 65.455801287880831);
#     ctx.lineTo(83.439707593222778, 65.061047983193674);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.099130512082681, 99.114526806947524);
#     ctx.lineTo(92.5122698553444, 144.90627485382251);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(88.542061941505395, 140.4076696120959);
#     ctx.lineTo(88.982393048078393, 133.35032531579122);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.242975168749673, 98.340256562819249);
#     ctx.lineTo(7.4512011959503353, 121.67853955294682);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(12.772236211650679, 118.90607019122416);
#     ctx.lineTo(19.516823192836512, 121.02987490287224);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.973291002307967, 98.75679201115797);
#     ctx.lineTo(49.951707445179061, 42.641679706470477);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(50.274317080814598, 48.633000347447314);
#     ctx.lineTo(45.550391243030184, 53.894608911290959);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.942431400993627, 98.60878931878031);
#     ctx.lineTo(43.7802543901837, 74.068802005756552);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(45.878896334351147, 79.689807430961281);
#     ctx.lineTo(42.94359343348674, 86.122846905438095);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(51.994975032548957, 98.640423233814062);
#     ctx.lineTo(41.820479335527473, 132.66404383928281);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(43.539514299289948, 126.91557284315157);
#     ctx.lineTo(49.762435932534714, 123.55770948284426);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(52.633658985905484, 99.25750477532894);
#     ctx.lineTo(122.84490166168673, 75.601582839293783);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(117
# <canvas id="jp_svg_canvas_fake_svg_7" width="1049.0" height="1049.0" style="border:1px solid #d3d3d3;">
# Your browser does not support the HTML5 canvas tag.</canvas>
# <script>
# (function () {
#     var c = document.getElementById("jp_svg_canvas_fake_svg_7");
#     var ctx = c.getContext("2d");
#     var visible = false;
#     var showhide = function () {
#         if (visible) {
#             $(c).show();
#         } else {
#             $(c).hide();
#         }
#     };
#     var toggle_visibility = function() {
#         visible = !visible;
#         showhide();
#     };
#     showhide();
#     // format the canvas
#     ctx.scale(6.5073180188039155, 6.5073180188039155);
#     ctx.translate(2.71875, -13.953125);
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(65.766983924106981, 124.5515932469999);
#     ctx.lineTo(89.128594336704637, 153.6223482518827);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(85.370132110987129, 148.94538751890079);
#     ctx.lineTo(86.135547533707452, 141.91586838665128);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(66.357303662918724, 123.78038100127981);
#     ctx.lineTo(13.605117841385523, 100.67884901885793);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(19.101202564309165, 103.08572515161703);
#     ctx.lineTo(21.675543056112957, 109.67152586468598);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(104.82054178506125, 99.364594458449503);
#     ctx.lineTo(146.64151041299093, 100.01298618208232);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(140.64223140378445, 99.919973442661075);
#     ctx.lineTo(135.72034284563009, 94.843063652137985);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(70.425578009974132, 67.568287123833485);
#     ctx.lineTo(113.51247469695305, 40.159849548653959);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(108.4499472273634, 43.380224623028077);
#     ctx.lineTo(101.54752844072691, 41.845097627015129);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(70.657167339403472, 67.153197979957383);
#     ctx.lineTo(71.127891235855046, 32.483896146965357);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(71.04643349277859, 38.483343174491552);
#     ctx.lineTo(65.97901285060972, 43.415000911532999);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.757552525372489, 66.845958226365383);
#     ctx.lineTo(45.425404717722493, 99.212594656312802);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(49.030824017750099, 94.41666391546714);
#     ctx.lineTo(56.031949051811154, 93.424571048118764);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(70.373144803191195, 66.695440170594395);
#     ctx.lineTo(20.138689485165227, 42.642391236772291);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(25.550325454444632, 45.233567829751117);
#     ctx.lineTo(27.900708268028453, 51.902578298299645);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.81971887953712, 67.515323693018587);
#     ctx.lineTo(104.49079830577385, 99.233568399333194);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(100.06383200596295, 95.183633908463179);
#     ctx.lineTo(103.43877741502131, 91.494495325287431);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(69.900305493732219, 66.717459584446758);
#     ctx.lineTo(13.147636903611527, 100.7079058288473);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(18.29503990666262, 97.625010708318456);
#     ctx.lineTo(25.153621676312572, 99.345433943753662);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(65.828569041523707, 123.86114814117504);
#     ctx.lineTo(33.119058238301051, 152.31520392730786);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(37.645937282481839, 148.37726460332675);
#     ctx.lineTo(44.699952589283427, 148.86804770349315);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(66.542928532554257, 123.92081728682312);
#     ctx.lineTo(46.211263493491764, 99.195475489948123);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(50.022112789895566, 103.82985005833366);
#     ctx.lineTo(49.335841729910783, 110.86753661232478);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(66.43102502686564, 124.65643422624424);
#     ctx.lineTo(105.10258722168986, 99.282700705736431);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#ff0000';
#     ctx.lineWidth = 1;
#     ctx.moveTo(100.08603324504011, 102.57423320585846);
#     ctx.lineTo(97.343089494938425, 98.393771558650343);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(66.65550767297448, 124.27333778546586);
#     ctx.lineTo(70.655990441561968, 67.181359558643436);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.strokeStyle = '#00d300';
#     ctx.lineWidth = 1;
#     ctx.moveTo(70.236593754252951, 73.166683812071497);
#     ctx.lineTo(64.899326303638716, 77.804956783837369);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.fillStyle = '#73f273';
#     ctx.arc(113.24411010742188, 39.737972259521484, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#c9e9c9';
#     ctx.arc(66.156730651855469, 124.23838806152344, 7, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#adecad';
#     ctx.arc(70.157213420442957, 67.146409834701018, 7, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#9cee9c';
#     ctx.arc(70.627937316894531, 32.477108001708984, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#5bf55b';
#     ctx.arc(45.825065612792969, 99.513046264648438, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#62f462';
#     ctx.arc(13.404544830322266, 101.13685607910156, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#4bf64b';
#     ctx.arc(19.922758102416992, 43.093360900878906, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#eca9a9';
#     ctx.arc(146.64926147460938, 99.513046264648438, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#eda2a2';
#     ctx.arc(104.82829284667969, 98.864654541015625, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#81f081';
#     ctx.arc(89.518341064453125, 153.30914306640625, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.beginPath();
#     ctx.fillStyle = '#a1eda1';
#     ctx.arc(33.447219848632812, 152.69244384765625, 3, 0, Math.PI * 2);
#     ctx.fill();
#     ctx.font = '10px Arial';
#     ctx.fillStyle = 'black';
#     ctx.textAlign = 'center';
#     ctx.fillText('ccl3', 113.24411010742188, 35.737972259521484);
#     ctx.font = '15px Arial';
#     ctx.fillStyle = 'black';
#     ctx.textAlign = 'center';
#     ctx.fillText('irf1', 66.156730651855469, 120.23838806152344);
#     ctx.font = '15px Arial';
#     ctx.fillStyle = 'black';
#     ctx.textAlign = 'center';
#     ctx
